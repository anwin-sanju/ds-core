# %%
#Introduction

print("Hello World")
# Out:
# Hello World

# %%
print(2 + 3)
print(5 - 2)
print(5 * 2)
print(6 / 2)
# Out:
# 5
# 3
# 10
# 3.0

# %%
print(3 ** 2)
print(5 // 2)
print(5 % 3)
# Out:
# 9
# 2
# 2

# %%
print(type(10))
print(type(3.14))
print(type(1 + 4j))
print(type('Hazel'))
print(type([1, 2, 3]))
print(type({3.14, 2.11, 9}))
print(type({'name': 'Hazel'}))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'set'>
# <class 'dict'>
