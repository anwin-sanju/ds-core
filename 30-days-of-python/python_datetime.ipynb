# %% [markdown]
# ## Notes

# %%
import datetime
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'sys', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
from datetime import datetime
now = datetime.now()
print(now)
# Out:
# 2026-07-27 11:13:55.067620

# %%
day = now.day
month = now.month
year = now.year
hour = now.hour
minute = now.minute
second = now.second
timestamp = now.timestamp()
print(day, month, year, hour, minute)
# Out:
# 27 7 2026 11 13

# %%
print("timestamp", timestamp)
print(f"{day}/{month}/{year}, {hour}:{minute}")
# Out:
# timestamp 1785131035.06762
# 27/7/2026, 11:13

# %%
new_year = datetime(2020, 1, 1)
print(new_year)
# Out:
# 2020-01-01 00:00:00

# %%
day = new_year.day
month = new_year.month
year = new_year.year
hour = new_year.hour
minute = new_year.minute
second = new_year.second
print(day, month, year, hour, minute)
print(f'{day}/{month}/{year}, {hour}:{minute}')
# Out:
# 1 1 2020 0 0
# 1/1/2020, 0:0

# %%
now = datetime.now()
t = now.strftime("%H:%M:%S")
print("time:", t)
# Out:
# time: 11:22:23

# %%
time_one = now.strftime("%m/%d/%Y, %H:%M:%S")
print(time_one)
# Out:
# 07/27/2026, 11:22:23

# %%
time_two = now.strftime("%d/%m/%Y, %H:%M:%S")
print(time_two)
# Out:
# 27/07/2026, 11:22:23

# %%
date_string = "5 December, 2019"
print("date_string =", date_string)
date_object = datetime.strptime(date_string, "%d %B, %Y")
print("date_object =", date_object)
# Out:
# date_string = 5 December, 2019
# date_object = 2019-12-05 00:00:00

# %%
from datetime import date
d = date(2020, 1, 1)
print(d)
print("Current date: ", date.today())
# Out:
# 2020-01-01
# Current date:  2026-07-27

# %%
today = date.today()
print("Current year:", today.year)
print("Current month:", today.month)
print("Current day:", today.day)
# Out:
# Current year: 2026
# Current month: 7
# Current day: 27

# %%
from datetime import time
# time(hour = 0, minute = 0, second = 0)
a = time()
print("a =", a)     # a = 00:00:00
# time(hour, minute and second)
b = time(10, 30, 50)
print("b =", b)     # b = 10:30:50
# time(hour, minute and second)
c = time(hour=10, minute=30, second=50)
print("c =", c)     # c = 10:30:50
# time(hour, minute, second, microsecond)
d = time(10, 30, 50, 200555)
print("d =", d)
# Out:
# a = 00:00:00
# b = 10:30:50
# c = 10:30:50
# d = 10:30:50.200555

# %%
from datetime import date, datetime

today = date(year=2026, month=7, day=27)
new_year = date(year=2027, month=1, day=1)
time_left_for_newyear = new_year - today
print('Time left for new year: ', time_left_for_newyear)
# Out:
# Time left for new year:  158 days, 0:00:00

# %%
t1 = datetime.now()
t2 = datetime(year = 2027, month = 1, day = 1, hour = 0, minute = 0, second = 0)

diff = t2 - t1
print('Time left for new year:', diff)
# Out:
# Time left for new year: 157 days, 12:14:15.271447

# %%
from datetime import timedelta
t1 = timedelta(weeks=12, days=10, hours=4, seconds=20)
t2 = timedelta(days=7, hours=5, minutes=3, seconds=30)
t3 = t1 - t2
print("t3 =", t3)
# Out:
# t3 = 86 days, 22:56:50

# %% [markdown]
# ## Exercises

# %%
now = datetime.now()
day = now.day
month = now.month
year = now.year
hour = now.hour
minute = now.minute
timestamp = now.timestamp()

print(f"{day}/{month}/{year} {hour}:{minute} {timestamp}")
# Out:
# 27/7/2026 11:57 1785133633.716069

# %%
now = datetime.now()
t = now.strftime("%m/%d/%Y, %H:%M:%S")
print(t)
# Out:
# 07/27/2026, 12:00:00

# %%
today_str = "5 December, 2019"
today = datetime.strptime(today_str, "%d %B, %Y")
print(today)
# Out:
# 2019-12-05 00:00:00

# %%
t1 = datetime.now()
t2 = datetime(year = 2027, month = 1, day = 1, hour = 0, minute = 0, second = 0)

diff = t2 - t1
print('Time left for new year:', diff)
# Out:
# Time left for new year: 157 days, 11:55:42.308522

# %%
t1 = datetime.now()
t2 = datetime(year=1970, month=1, day=1, hour = 0, minute = 0, second = 0)
t3 = t1 - t2
print(t3)
# Out:
# 20661 days, 12:06:26.755695
