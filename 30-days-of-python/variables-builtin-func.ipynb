# %%
# Built-in Functions

print("I'm Hazel!")
print(len("I'm Hazel"))
print(str(10))
print(int('10'))
print(float(10))
input("Enter your name: ")
# Out:
# I'm Hazel!
# 9
# 10
# 10
# 10.0
# 'Hazel'

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               break               for                 not
# None                class               from                or
# True                continue            global              pass
# __peg_parser__      def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield

# %%
print(min(20, 10, 30, 5, 26))
print(max(0, 10, 30, 5, 26))
print(min([20, 10, 30, 5, 26]))
print(max([0, 10, 30, 5, 26]))
print(sum([0, 10, 30, 5, 26]))
# Out:
# 5
# 30
# 5
# 30
# 71

# %%
first_name = 'Hazel'
last_name = 'Lestrange'
country = 'India'
city = 'Kannur'
age = '22'
is_alive = True
skills = ['poetry', 'storytelling', 'painting']
personal_info = {
    'firstname': 'Hazel',
    'lastname': 'Lestrange',
    'country': 'India',
    'age': '22'
}

# %%
print("First name: ", first_name)
print("First name length: ", len(first_name))
print("Personal info: ", personal_info)
# Out:
# First name:  Hazel
# First name length:  5
# Personal info:  {'firstname': 'Hazel', 'lastname': 'Lestrange', 'country': 'India', 'age': '22'}

# %%
first, second, third = 'cat', 'dog', 'bat'
print(first, second, third)
# Out:
# cat dog bat

# %%
favourite_fruit = input("What is your favourite fruit? ")
print("Your favourite fruit is", favourite_fruit)
# Out:
# Your favourite fruit is Apple

# %%
gravity = 9.81
print(gravity)
print(int(gravity))
# Out:
# 9.81
# 9

# %%
#The radius of a circle is 30 meters.
# 1) Calculate the area of a circle and assign the value to a variable name of area_of_circle
# 2) Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
# 3) Take radius as user input and calculate the area.

import math

def area_of_circle(radius):
    return math.pi * (radius ** 2)

def circum_of_circle(radius):
    return 2 * math.pi * radius

radius = int(input("Enter the radius of the circle: "))
area = area_of_circle(radius)
circumference = circum_of_circle(radius)
print(f"Area is {area} and circumference is {circumference}.")
# Out:
# Area is 1963.4954084936207 and circumference is 157.07963267948966.
