# %% [markdown]
# # Notes

# %%
empty_dict = {}
print(type(empty_dict))
dct = {'key1': 'value1', 'key2': 'value2'}
print(dct)
# Out:
# <class 'dict'>
# {'key1': 'value1', 'key2': 'value2'}

# %%
personal_info = {
    'name': 'Hazel',
    'age': 18,
    'country': 'India',
    'skills': ['HTML', 'CSS', 'Javascript'],
    'address': {
        'street': 'Space Street',
        'pincode':  560074
    }
}
print(personal_info)
print(len(personal_info))
# Out:
# {'name': 'Hazel', 'age': 18, 'country': 'India', 'skills': ['HTML', 'CSS', 'Javascript'], 'address': {'street': 'Space Street', 'pincode': 560074}}
# 5

# %%
print(personal_info['name'])
# Out:
# Hazel

# %%
print(personal_info['skills'][0])
# Out:
# HTML

# %%
print(personal_info['address']['street'])
# Out:
# Space Street

# %%
print(personal_info.get('name'))
# Out:
# Hazel

# %%
print(personal_info.get('skills'))
# Out:
# ['HTML', 'CSS', 'Javascript']

# %%
print(personal_info.get('address').get('street'))
# Out:
# Space Street

# %%
print(personal_info.get('skills')[0])
# Out:
# HTML

# %%
dct['key3'] = 'value3'
print(dct)
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
personal_info['skills'].append('React')
print(personal_info)
# Out:
# {'name': 'Hazel', 'age': 18, 'country': 'India', 'skills': ['HTML', 'CSS', 'Javascript', 'React', 'React'], 'address': {'street': 'Space Street', 'pincode': 560074}}

# %%
personal_info['skills'].pop(len(personal_info['skills']) - 1)
# Out:
# 'React'

# %%
dct['key1'] = 'value-one'
print(dct)
# Out:
# {'key1': 'value-one', 'key2': 'value2', 'key3': 'value3'}

# %%
print('key1' in dct)
print('key5' in dct)
# Out:
# True
# False

# %%
dct.pop('key1')
print(dct)
# Out:
# {'key2': 'value2', 'key3': 'value3'}

# %%
dct.popitem()
print(dct)
# Out:
# {'key2': 'value2'}

# %%
del dct

# %%
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
print(dct.items())
# Out:
# dict_items([('key1', 'value1'), ('key2', 'value2'), ('key3', 'value3'), ('key4', 'value4')])

# %%
dct.clear()
print(dct)
# Out:
# {}

# %%
del dct

# %%
dct = {'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'}
dct_copy = dct.copy()

# %%
keys = dct.keys()
values = dct.values()
print(keys)
print(values)
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4'])
# dict_values(['value1', 'value2', 'value3', 'value4'])

# %% [markdown]
# # Exercises

# %%
dog = {}

# %%
dog['name'] = 'Cheif'
dog['breed'] = 'German Shepherd'
dog['legs'] = 4
dog['age'] = 2
print(dog)
# Out:
# {'name': 'Cheif', 'breed': 'German Shepherd', 'legs': 4, 'age': 2}

# %%
student = {
    'first_name': 'Hazel',
    'last_name': 'Lestrange',
    'gender': 'female',
    'age': 22,
    'marital_status': False,
    'skills': ['HTML', 'CSS', 'JavaScript'],
    'address': {
        'country': 'India',
        'city': 'Kannur',
        'pincode': 560072
    }
}
print(dct)
print(len(dct))
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}
# 4

# %%
print(student['skills'])
print(type(student['skills']))
# Out:
# ['HTML', 'CSS', 'JavaScript']
# <class 'list'>

# %%
student['skills'].append('React')
print(student['skills'])
# Out:
# ['HTML', 'CSS', 'JavaScript', 'React']

# %%
keys = student.keys()
values = student.values()

# %%
print(keys, values)
# Out:
# dict_keys(['first_name', 'last_name', 'gender', 'age', 'marital_status', 'skills', 'address']) dict_values(['Hazel', 'Lestrange', 'female', 22, False, ['HTML', 'CSS', 'JavaScript', 'React'], {'country': 'India', 'city': 'Kannur', 'pincode': 560072}])

# %%
student_lst = student.items()
print(student_lst)
# Out:
# dict_items([('first_name', 'Hazel'), ('last_name', 'Lestrange'), ('gender', 'female'), ('age', 22), ('marital_status', False), ('skills', ['HTML', 'CSS', 'JavaScript', 'React']), ('address', {'country': 'India', 'city': 'Kannur', 'pincode': 560072})])

# %%
student.pop('marital_status')
print(student.get('marital_status'))
# Out:
# None

# %%
del student
