# %%
empty_tuple = tuple()
brothers = ('Messi', 'Neymar', 'Ronaldo')
sisters = ('Anne', 'Emma')
siblings = brothers + sisters
print(siblings)
print(len(siblings))
# Out:
# ('Messi', 'Neymar', 'Ronaldo', 'Anne', 'Emma')
# 5

# %%
parents = ('Miroslav', 'Frieda')
family_members = siblings + parents
print(family_members, len(family_members))
# Out:
# ('Messi', 'Neymar', 'Ronaldo', 'Anne', 'Emma', 'Miroslav', 'Frieda') 7

# %%
*siblings, father, mother = family_members
parents = (father, mother)

print(siblings)
print(parents)
# Out:
# ['Messi', 'Neymar', 'Ronaldo', 'Anne', 'Emma']
# ('Miroslav', 'Frieda')

# %%
fruits = ("Apple", "Banana", "Mango")
vegetables = ("Carrot", "Tomato", "Potato")
animal_products = ("Milk", "Egg", "Cheese")

food_stuff_tp = fruits + vegetables + animal_products
food_stuff_lt = list(food_stuff_tp)
print(food_stuff_lt)
# Out:
# ['Apple', 'Banana', 'Mango', 'Carrot', 'Tomato', 'Potato', 'Milk', 'Egg', 'Cheese']

# %%
print(food_stuff_tp[len(food_stuff_tp)//2])
# Out:
# Tomato

# %%
print(food_stuff_tp[:3])
print(food_stuff_tp[-3:])
# Out:
# ('Apple', 'Banana', 'Mango')
# ('Milk', 'Egg', 'Cheese')

# %%
del food_stuff_tp

# %%
nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')

# %%
print('Estonia' in nordic_countries)
print('Iceland' in nordic_countries)
# Out:
# False
# True
