# %%
language = 'python'
a,b,c,d,e,f = language

print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# p
# y
# t
# h
# o
# n

# %%
print(language[0])
last_index = len(language) - 1
print(language[last_index])
# Out:
# p
# n

# %%
print(language[-1])
print(language[-2])
# Out:
# n
# o

# %%
first_three = language[0:3]
print(first_three)
last_three = language[3:6]
print(last_three)
# Out:
# pyt
# hon

# %%
last_two = language[-2:]
print(last_two)
# Out:
# on

# %%
#Reversing a string
greeting = "Hello World!"
print(greeting[::-1])
print(greeting[::2])
# Out:
# !dlroW olleH
# HloWrd

# %%
challenge = 'thirty days of python'
print(challenge.count('th'))
print(challenge.count('y'))
print(challenge.count('y', 7, 14))
# Out:
# 2
# 3
# 1

# %%
print(challenge.endswith('on'))
print(challenge.endswith('tion'))
# Out:
# True
# False

# %%
print(challenge.find('y'))
print(challenge.find('th'))
print(challenge.rfind('y'))
print(challenge.rfind('th'))
# Out:
# 5
# 0
# 16
# 17

# %%
sub_string = 'da'
print(challenge.index(sub_string)) 
print(challenge.rindex(sub_string)) 
print(challenge.isalnum()) # False, space is not an alphanumeric character
# Out:
# 7
# 7
# False

# %%
# 1) Concatenate the string 'Thirty', 'Days', 'Of', 'Python' to a single string, 'Thirty Days Of Python'.
# 2) Concatenate the string 'Coding', 'For' , 'All' to a single string, 'Coding For All'.

_30daysofpython = 'Thirty' + 'Days' + 'of' + 'Python'
codingforall = "Coding" + "for" + "All"
print(_30daysofpython)
print(codingforall)
# Out:
# ThirtyDaysofPython
# CodingforAll

# %%
# 3) Declare a variable named company and assign it to an initial value "Coding For All".
# 4 to 8
company = "Coding For All"
print(company)
print(len(company))
print(company.upper())
print(company.lower())
print(company.capitalize())
print(company.title())
print(company.swapcase())
# Out:
# Coding For All
# 14
# CODING FOR ALL
# coding for all
# Coding for all
# Coding For All
# cODING fOR aLL

# %%
#9
print(company[0])
# Out:
# C

# %%
#10

print(company.index('Coding'))
print(company.find('Coding'))

print(company.replace('Coding', 'Python'))
print(company.replace('All', 'Everyone'))
# Out:
# 0
# 0
# Python For All
# Coding For Everyone

# %%
print(company.split())
# Out:
# ['Coding', 'For', 'All']

# %%
companies = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print(companies.split(', '))
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
last_index = len(company) - 1
print(f"Last index is {last_index}")
print(company[10]) #space
# Out:
# Last index is 13

# %%
phrase = "Python For Everyone"
acronym = ""

for word in phrase.split():
    acronym += word[0].upper()

print(acronym)
# Out:
# PFE

# %%
print(company.index('C'))
print(company.index('F'))
print(company.rfind('i'))
# Out:
# 0
# 7
# 3

# %%
sample_sentence = "You cannot end a sentence with because because because is a conjunction"
print(sample_sentence.index('because'))
print(sample_sentence.rindex('because'))
# Out:
# 31
# 47

# %%
start = sample_sentence.find('because because because')
end = start + len('because because because')

print(sample_sentence[start:end])
# Out:
# because because because

# %%
print(company.startswith('Coding'))
print(company.endswith('All'))
# Out:
# True
# True

# %%
_trim = '  Coding For All      '
print(_trim.strip())
# Out:
# Coding For All

# %%
print('30DaysOfPython'.isidentifier())
print('thirty_days_of_python'.isidentifier())
# Out:
# False
# True

# %%
libraries = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
result = " #".join(libraries)
print(result)
# Out:
# Django #Flask #Bottle #Pyramid #Falcon

# %%
paragraph = """
I am enjoying this challenge.\nI just wonder what is next.
""" 
print(paragraph)
# Out:
# I am enjoying this challenge.
# I just wonder what is next.

# %%
print("Name \t Age \t Country \t City")
print("Hazel \t 22 \t India \t Kannur")
# Out:
# Name 	 Age 	 Country 	 City
# Hazel 	 22 	 India 	 Kannur

# %%
radius = 10
area = 3.14 * radius ** 2
print(f"The area of a circle with a radius {radius} is {area} meters square.")
# Out:
# The area of a circle with a radius 10 is 314.0 meters square.
