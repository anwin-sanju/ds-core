# %%
# 1) Declare your age as integer variable
age = 22

# 2) Declare your height as a float variable
height = 1.88

# 3) Declare a variable that store a complex number
_complex = 2 + 3j

# %%
# 4) Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).

def area_of_triangle(base, height):
    return 0.5 * base * height

base = float(input("Enter the base: "))
height = float(input("Enter the height: "))
area = area_of_triangle(base, height)

print(f"The area of the triangle is {area} cm^2")
# Out:
# The area of the triangle is 21.0 cm^2

# %%
# 5) Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).

def perimeter_of_triangle(side_a, side_b, side_c):
    return side_a + side_b + side_c

side_a = int(input("Enter length of Side 1: "))
side_b = int(input("Enter length of Side 2: "))
side_c = int(input("Enter length of Side 3: "))

perimeter = perimeter_of_triangle(side_a, side_b, side_c)
print(f"The perimeter of the triangle is {perimeter} cm")
# Out:
# The perimeter of the triangle is 90 cm

# %%
# 6) Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))

def rectangle(length, width):
    area = length * width
    perimeter = 2 * (length + width)

    return area, perimeter

length = float(input("Enter the length: "))
width = float(input("Enter the width: "))
area, perimeter = rectangle(length, width)
print(f"The area is {area} cm^2 and perimeter is {perimeter} cm")
# Out:
# The area is 1452.0 cm^2 and perimeter is 154.0 cm

# %%
# 7) Get radius of a circle using prompt. Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14. 

import math

def area_of_circle(radius):
    return math.pi * (radius ** 2)

def circum_of_circle(radius):
    return 2 * math.pi * radius

radius = int(input("Enter the radius of the circle: "))
area = area_of_circle(radius)
circumference = circum_of_circle(radius)
print(f"Area is {area} and circumference is {circumference}.")
# Out:
# Area is 1661.9025137490005 and circumference is 144.51326206513048.

# %%
# 8) Calculate the slope, x-intercept and y-intercept of y = 2x -2

# y = mx + c
m = 2
c = -2

# slope is the coefficient of x
slope = m

# y-intercept (x = 0)
y_intercept = (0, c)

# x-intercept (y = 0)
x_intercept = (-c / m, 0)

print(f"Slope is {slope}, X-intercept is {x_intercept} and Y_intercept is {y_intercept}.")
# Out:
# Slope is 2, X-intercept is (1.0, 0) and Y_intercept is (0, -2).

# %%
# 9) Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)

x1 = 2
x2 = 6
y1 = 2
y2 = 10

slope = (y2 - y1) / (x2 - x1)
print(f"The slope is {slope}")
# Out:
# The slope is 2.0.

# %%
# 12) Find the length of 'python' and 'dragon' and make a falsy comparison statement.

print(len('dragon') != len('python'))
# Out:
# False

# %%
# 13) Use and operator to check if 'on' is found in both 'python' and 'dragon'

print('on' in 'python' and 'on' in 'dragon')
# Out:
# True

# %%
# 14) I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.

sentence = 'I hope this course is not full of jargon.'
print('jargon' in sentence)
# Out:
# True

# %%
# 15) There is no 'on' in both dragon and python

print('on' not in 'python' and 'on' not in 'dragon')
# Out:
# False

# %%
# 16) Find the length of the text python and convert the value to float and convert it to string

_len = len('python')
float_len = float(_len)
str_len = str(float_len)

print(float_len)
print(type(str_len))
# Out:
# 6.0
# <class 'str'>

# %%
# 17) Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?

num = 5
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
# 18) Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.

print((7 // 3) == int(2.7))
# Out:
# True

# %%
# 19) Check if type of '10' is equal to type of 10

print(type('10') == type(10))

# 20) Check if int('9.8') is equal to 10

print(int(float('9.8')) == 10)
# Out:
# False
# False

# %%
# 21) Write a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?

hours = int(input("Enter hours worked: "))
rate = int(input("Enter rate per hour: "))
earn = hours * rate

print(f"Your weekly earning is {earn}")
# Out:
# Your weekly earning is 1120

# %%
# 22) Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years

num_years = int(input("Enter number of years lived: "))
seconds_in_a_year = 31536000

seconds_lived = num_years * seconds_in_a_year
print(f"You have lived for {seconds_lived} seconds.")
# Out:
# You have lived for 3153600000 seconds.

# %%
# 23) Write a Python script that displays the following table

for x in range(1,6):
    print(x, 1, x, x**2, x**3)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
